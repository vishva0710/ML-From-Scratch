# %% [markdown]
# Probability Distribution Function

# %%
# the Probability Distribution Function  is the tool we use to describe the distribution of a random variable. It tells us how the probability is spread across possible values. 
# the random variable are two types
# 1.Discrete Random Variable
#--Takes countable values (usually integers).
#2. Continuous Random Variable
#--Takes uncountable values within an interval (real numbers).
#It’s the mathematical description of how a random variable is distributed.
#Discrete case → PMF
#Continuous case → PDF
#Both cases → CDF
